# %% [markdown]
# Mini EDA de sitios donde se guardan los archivos adjuntos

# %%
import boto3
import pyarrow
import numpy as np
import pandas as pd

# %%
f = f's3://inai-summerofdata/parquet/inai.parquet'
df = pd.read_parquet(f, engine='pyarrow')
df.head()
# Out:
#            FOLIO       FECHASOLICITUD  \
# 0  1857500001912  2012/01/01 05:04:07
# 1  1857500002012  2012/01/01 05:13:16
# 2  0001800000712  2012/01/01 09:46:39
# 3  0000600003712  2012/01/01 10:11:41
# 4  0001500002812  2012/01/01 10:32:15
#
#                                          DEPENDENCIA    ESTATUS MEDIOENTRADA  \
# 0                     PEMEX EXPLORACIÓN Y PRODUCCIÓN  Terminada  Electrónica
# 1                     PEMEX EXPLORACIÓN Y PRODUCCIÓN  Terminada  Electrónica
# 2                              SECRETARÍA DE ENERGÍA  Terminada  Electrónica
# 3           SECRETARÍA DE HACIENDA Y CRÉDITO PÚBLICO  Terminada  Electrónica
# 4  SECRETARÍA DE DESARROLLO AGRARIO  TERRITORIAL ...  Terminada  Electrónica
#
#          TIPOSOLICITUD                               DESCRIPCIONSOLICITUD  \
# 0  Información Pública  Copia de los documentos y los datos con que cu...
# 1  Información Pública  Del ATG  para precisar información y datos usa...
# 2  Información Pública  Agradeceré se me proporcione en archivo magnét...
# 3  Información Pública  Agradeceré se me proporcione en archivo magnét...
# 4  Información Pública  Agradeceré se me proporcione en archivo magnét...
#
#   OTROSDATOS ARCHIVOADJUNTOSOLICITUD                        MEDIOENTREGA  ...  \
# 0       None                    None  Entrega por Internet en el INFOMEX  ...
# 1       None                    None  Entrega por Internet en el INFOMEX  ...
# 2       None                    None  Entrega por Internet en el INFOMEX  ...
# 3       None                    None  Entrega por Internet en el INFOMEX  ...
# 4       None                    None  Entrega por Internet en el INFOMEX  ...
#
#                                     ARCHIVORESPUESTA FECHARESPUESTA    PAIS  \
# 0  https://www.infomex.org.mx/gobiernofederal/mod...     2012/03/02  México
# 1  https://www.infomex.org.mx/gobiernofederal/mod...     2012/03/02  México
# 2  https://www.infomex.org.mx/gobiernofederal/mod...     2012/02/02  México
# 3  https://www.infomex.org.mx/gobiernofederal/mod...     2012/02/02  México
# 4  https://www.infomex.org.mx/gobiernofederal/mod...     2012/02/01  México
#
#              ESTADO       MUNICIPIO CODIGOPOSTAL                      SECTOR  \
# 0  Distrito Federal   BENITO JUAREZ         3100                     Energía
# 1  Distrito Federal   BENITO JUAREZ         3100                     Energía
# 2  Distrito Federal  MIGUEL HIDALGO        11230                     Energía
# 3  Distrito Federal  MIGUEL HIDALGO        11230  Hacienda y Crédito Público
# 4  Distrito Federal  MIGUEL HIDALGO        11230             Reforma Agraria
#
#   tipo_archivo_respuesta cantidad_archivos_respuesta  \
# 0                    pdf                         1.0
# 1                    pdf                         1.0
# 2                    zip                         2.0
# 3                    pdf                         1.0
# 4                    zip                         4.0
#
#                              texto_respuesta_adjunto
# 0   PEMEX EXPLORACION Y PRODUCCION Oficio Fecha 0...
# 1   PEMEX EXPLORACION Y PRODUCCION Oficio Fecha 0...
# 2                                               None
# 3   INIDOS SECRETARIA DE HACIENDA Y CREDITO PUBLI...
# 4                                               None
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Extracción del dominio del archivo de respuesta

# %%
my_df = df[~df['ARCHIVORESPUESTA'].isnull()]
#my_df.head()
my_df['site_url'] = my_df['ARCHIVORESPUESTA']
#my_df.head()
my_df.loc[my_df["site_url"].str.contains('infomex.org.mx', case=False, na=None), "site_url"] = 'infomex.org.mx'
my_df.head()
#df['ARCHIVORESPUESTA'].str.extract()
# Out:
# <ipython-input-3-89352743136d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_df['site_url'] = my_df['ARCHIVORESPUESTA']
# /home/rafaelortega/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#            FOLIO       FECHASOLICITUD  \
# 0  1857500001912  2012/01/01 05:04:07
# 1  1857500002012  2012/01/01 05:13:16
# 2  0001800000712  2012/01/01 09:46:39
# 3  0000600003712  2012/01/01 10:11:41
# 4  0001500002812  2012/01/01 10:32:15
#
#                                          DEPENDENCIA    ESTATUS MEDIOENTRADA  \
# 0                     PEMEX EXPLORACIÓN Y PRODUCCIÓN  Terminada  Electrónica
# 1                     PEMEX EXPLORACIÓN Y PRODUCCIÓN  Terminada  Electrónica
# 2                              SECRETARÍA DE ENERGÍA  Terminada  Electrónica
# 3           SECRETARÍA DE HACIENDA Y CRÉDITO PÚBLICO  Terminada  Electrónica
# 4  SECRETARÍA DE DESARROLLO AGRARIO  TERRITORIAL ...  Terminada  Electrónica
#
#          TIPOSOLICITUD                               DESCRIPCIONSOLICITUD  \
# 0  Información Pública  Copia de los documentos y los datos con que cu...
# 1  Información Pública  Del ATG  para precisar información y datos usa...
# 2  Información Pública  Agradeceré se me proporcione en archivo magnét...
# 3  Información Pública  Agradeceré se me proporcione en archivo magnét...
# 4  Información Pública  Agradeceré se me proporcione en archivo magnét...
#
#   OTROSDATOS ARCHIVOADJUNTOSOLICITUD                        MEDIOENTREGA  ...  \
# 0       None                    None  Entrega por Internet en el INFOMEX  ...
# 1       None                    None  Entrega por Internet en el INFOMEX  ...
# 2       None                    None  Entrega por Internet en el INFOMEX  ...
# 3       None                    None  Entrega por Internet en el INFOMEX  ...
# 4       None                    None  Entrega por Internet en el INFOMEX  ...
#
#   FECHARESPUESTA    PAIS            ESTADO       MUNICIPIO CODIGOPOSTAL  \
# 0     2012/03/02  México  Distrito Federal   BENITO JUAREZ         3100
# 1     2012/03/02  México  Distrito Federal   BENITO JUAREZ         3100
# 2     2012/02/02  México  Distrito Federal  MIGUEL HIDALGO        11230
# 3     2012/02/02  México  Distrito Federal  MIGUEL HIDALGO        11230
# 4     2012/02/01  México  Distrito Federal  MIGUEL HIDALGO        11230
#
#                        SECTOR tipo_archivo_respuesta  \
# 0                     Energía                    pdf
# 1                     Energía                    pdf
# 2                     Energía                    zip
# 3  Hacienda y Crédito Público                    pdf
# 4             Reforma Agraria                    zip
#
#   cantidad_archivos_respuesta  \
# 0                         1.0
# 1                         1.0
# 2                         2.0
# 3                         1.0
# 4                         4.0
#
#                              texto_respuesta_adjunto        site_url
# 0   PEMEX EXPLORACION Y PRODUCCION Oficio Fecha 0...  infomex.org.mx
# 1   PEMEX EXPLORACION Y PRODUCCION Oficio Fecha 0...  infomex.org.mx
# 2                                               None  infomex.org.mx
# 3   INIDOS SECRETARIA DE HACIENDA Y CREDITO PUBLI...  infomex.org.mx
# 4                                               None  infomex.org.mx
#
# [5 rows x 24 columns]

# %%
my_df["site_url"].unique()
# Out:
# array(['infomex.org.mx', 'ADJUNTO'], dtype=object)

# %% [markdown]
# Todos los archivos se encuentran en una liga de infomex.org.mx, por lo que no tendría sentido hacer un análisis adicional al que se hizo con url's
